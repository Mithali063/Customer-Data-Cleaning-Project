# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.arduinoIDE',
#  '.bash_history',
#  '.cache',
#  '.codex',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.git-for-windows-updater',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.nbi',
#  '.packettracer',
#  '.streamlit',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda_projects',
#  'app.py',
#  'AppData',
#  'Application Data',
#  'Cisco Packet Tracer 9.0.0',
#  'Contacts',
#  'Cookies',
#  'data_cleaning_customer.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'label_encoder.pkl',
#  'Links',
#  'Local Settings',
#  'marketing_campaign-selected-columns.csv',
#  'Mithali0603-HelloWorld',
#  'model.pkl',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'notebook.html',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{71d54c77-e616-11ef-ab2e-005056c00008}.TM.blf',
# ...

# %%
df = pd.read_csv("marketing_campaign-selected-columns.csv")
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines
# 0  04-09-2012       58       635
# 1  08-03-2014       38        11
# 2  21-08-2013       26       426
# 3  10-02-2014       26        11
# 4  19-01-2014       94       173

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines
# 0  04-09-2012       58       635
# 1  08-03-2014       38        11
# 2  21-08-2013       26       426
# 3  10-02-2014       26        11
# 4  19-01-2014       94       173

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 0      5524        1957  Graduation         Single   58138.0        0
# 1      2174        1954  Graduation         Single   46344.0        1
# 2      4141        1965  Graduation       Together   71613.0        0
# 3      6182        1984  Graduation       Together   26646.0        1
# 4      5324        1981         PhD        Married   58293.0        1
# 5      7446        1967      Master       Together   62513.0        0
# 6       965        1971  Graduation       Divorced   55635.0        0
# 7      6177        1985         PhD        Married   33454.0        1
# 8      4855        1974         PhD       Together   30351.0        1
# 9      5899        1950         PhD       Together    5648.0        1
# 10     1994        1983  Graduation        Married       NaN        1
# 11      387        1976       Basic        Married    7500.0        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              2240 non-null   int64
#  1   Year_Birth      2240 non-null   int64
#  2   Education       2240 non-null   object
#  3   Marital_Status  2240 non-null   object
#  4   Income          2216 non-null   float64
#  5   Kidhome         2240 non-null   int64
#  6   Teenhome        2240 non-null   int64
#  7   Dt_Customer     2240 non-null   object
#  8   Recency         2240 non-null   int64
#  9   MntWines        2240 non-null   int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 175.1+ KB

# %%
df.isnull().sum()
# Out:
# ID                 0
# Year_Birth         0
# Education          0
# Marital_Status     0
# Income            24
# Kidhome            0
# Teenhome           0
# Dt_Customer        0
# Recency            0
# MntWines           0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace("year_birth", "marital_status")

# %%
df['income'] = df['income'].fillna(df['income'].mean())

# %%
df.isnull().sum()
# Out:
# id                0
# marital_status    0
# education         0
# marital_status    0
# income            0
# kidhome           0
# teenhome          0
# dt_customer       0
# recency           0
# mntwines          0
# dtype: int64

# %%
df['dt_customer'] = pd.to_datetime(df['dt_customer'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2240 non-null   int64
#  1   marital_status  2240 non-null   int64
#  2   education       2240 non-null   object
#  3   marital_status  2240 non-null   object
#  4   income          2240 non-null   float64
#  5   kidhome         2240 non-null   int64
#  6   teenhome        2240 non-null   int64
#  7   dt_customer     916 non-null    datetime64[ns]
#  8   recency         2240 non-null   int64
#  9   mntwines        2240 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 175.1+ KB

# %%
df = df.dropna(subset=['dt_customer'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['marital_status'] = df['marital_status'].replace({'Together': 'Partner'})

# %%
df.to_csv("cleaned_customer_data.csv", index=False)

# %%
df.shape
# Out:
# (916, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              916 non-null    int64
#  1   marital_status  916 non-null    int64
#  2   education       916 non-null    object
#  3   marital_status  916 non-null    object
#  4   income          916 non-null    float64
#  5   kidhome         916 non-null    int64
#  6   teenhome        916 non-null    int64
#  7   dt_customer     916 non-null    datetime64[ns]
#  8   recency         916 non-null    int64
#  9   mntwines        916 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 78.7+ KB

# %%
df.isnull().sum()
# Out:
# id                0
# marital_status    0
# education         0
# marital_status    0
# income            0
# kidhome           0
# teenhome          0
# dt_customer       0
# recency           0
# mntwines          0
# dtype: int64

# %%
df = df.dropna(subset=['dt_customer'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                0
# marital_status    0
# education         0
# marital_status    0
# income            0
# kidhome           0
# teenhome          0
# dt_customer       0
# recency           0
# mntwines          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              916 non-null    int64
#  1   marital_status  916 non-null    int64
#  2   education       916 non-null    object
#  3   marital_status  916 non-null    object
#  4   income          916 non-null    float64
#  5   kidhome         916 non-null    int64
#  6   teenhome        916 non-null    int64
#  7   dt_customer     916 non-null    datetime64[ns]
#  8   recency         916 non-null    int64
#  9   mntwines        916 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 78.7+ KB

# %%
df.columns
# Out:
# Index(['id', 'marital_status', 'education', 'marital_status', 'income',
#        'kidhome', 'teenhome', 'dt_customer', 'recency', 'mntwines'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (916, 10)

# %%
df.to_csv("cleaned_customer_data.csv", index=False)
